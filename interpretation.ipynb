# %%
# %%bash
# git clone https://github.com/ronakdm/input-marginalization.git
# cd input-marginalization
# git pull
# cd ..
# Out:
# Updating c23807f..a15fcc6
# Fast-forward
#  metrics.py | 60 ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  1 file changed, 60 insertions(+)
#  create mode 100644 metrics.py
# fatal: destination path 'input-marginalization' already exists and is not an empty directory.
# From https://github.com/ronakdm/input-marginalization
#    c23807f..a15fcc6  main       -> origin/main

# %%
import torch

# %%
import sys
sys.path.append("input-marginalization")

from metrics import zero_erasure, unk_erasure

# %%
from google.colab import drive
drive.mount('/content/gdrive')
save_dir = "/content/gdrive/My Drive/input-marginalization"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Apply GPU acceleration before loading the models.

# %%
cnn = torch.load(f"{save_dir}/cnn_sst2.pt")

# %%
bert = torch.load(f"{save_dir}/bert_sst2.pt")

# %%
sentences = [
  "a good piece of work more often than not .",
  "it ' s also , clearly , great fun .",
  "the best film about baseball to hit theaters since field of dreams .",
  "it ' s a bit disappointing that it only manages to be decent instead of dead brilliant ."
]

# %%
# BERT + Zero

for sentence in sentences:
  print(zero_erasure(bert, sentence))

# CNN + Zero

for sentence in sentences:
  print(zero_erasure(cnn, sentence))

# BERT + UNK

for sentence in sentences:
  print(unk_erasure(bert, sentence))

# CNN + UNK

for sentence in sentences:
  print(unk_erasure(cnn, sentence))
# Out:
# tensor([[0.4513, 0.3912, 5.1484, 1.9576, 0.6788, 1.1959, 0.0505, 0.6590, 3.0680,
#          0.2871, 0.1845, 1.3795]])
# tensor([[ 0.4941,  0.0623,  0.0716,  0.1391,  0.2452, -0.0377, -0.1223,  0.3507,
#           1.3578,  0.8738,  0.0500,  3.9080]])
# tensor([[ 2.2343e-01,  1.1295e+00,  5.1669e+00,  7.3011e-01,  4.6234e-01,
#           2.7806e-02,  4.7479e-02,  4.2601e-03, -4.4263e-02,  3.4822e-01,
#           1.1306e-01,  1.2601e-01,  2.7254e-02,  1.9085e-01,  5.3890e+00]])
# tensor([[ 0.1088,  0.1339,  0.0624,  0.0837,  0.2274, -0.0157,  0.5407, -0.0204,
#          -0.2026,  0.2152, -0.1340,  0.0707,  0.5725,  0.2908,  0.2974, -0.2238,
#          -0.3172, -0.3685,  0.0661,  1.9807]])
# tensor([[-0.5509,  0.7725,  1.4753,  1.7220,  1.5198,  1.8066,  0.4995,  2.1930,
#          -0.5475,  0.6141,  0.5077, -0.0402]])
# tensor([[ 0.0190, -0.3941,  0.8259, -0.8448, -0.6939,  1.5045,  2.1829,  1.5027,
#           1.1406,  1.8970,  0.6017, -0.2630]])
# tensor([[-0.0639,  0.1700, -0.7926,  0.5404,  0.4534,  0.0365, -0.2423,  0.4979,
#          -0.1015,  0.1987, -0.9425,  0.3927, -0.1233,  0.2289, -0.2183]])
# tensor([[ 0.0056, -0.0433, -0.1361, -0.4583, -0.7323, -1.2463,  0.4479,  0.5017,
#           0.3544, -0.9584, -1.4657, -0.8533, -0.0268, -0.4472,  0.2040, -0.1409,
#          -1.3065, -0.4763,  0.2911, -0.2417]])
# tensor([[0.1314, 0.2202, 4.5991, 1.1774, 0.1406, 1.1078, 0.1160, 1.2061, 4.5509,
#          0.4026, 0.2762, 2.4702]])
# tensor([[0.0079, 0.1959, 0.0765, 0.7131, 0.4183, 0.4694, 0.0538, 0.3437, 0.8055,
#          0.7206, 0.3301, 5.0633]])
# tensor([[ 7.8558e-02,  8.9270e-01,  3.8045e+00,  2.5798e-01,  7.5910e-02,
#          -6.7278e-02, -7.5734e-02,  4.7536e-03,  3.8707e-01,  3.4777e-01,
#           7.4426e-02,  3.1556e-01,  1.7919e-01,  3.8378e-01,  4.9713e+00]])
# tensor([[-0.0281,  0.0244, -0.0591,  0.1224, -0.1397,  0.1870,  0.6149,  0.0338,
#          -0.3441, -0.1194, -0.1552,  0.0728,  0.2385, -0.4048,  0.1005, -0.2912,
#          -0.2804, -0.5382, -0.0321,  0.8074]])
# tensor([[-0.7805,  0.2653,  0.0402, -0.2284, -1.1456, -0.2205, -2.4805, -0.0260,
#          -1.0920, -0.7491, -0.3070,  0.3641]])
# tensor([[ 0.0539, -0.1583, -0.3542, -1.5261, -1.9506,  0.0751,  0.7242, -1.3128,
#          -1.3605,  0.1691, -1.0108, -0.1268]])
# tensor([[-0.9794, -1.2734,  0.5288, -1.3847, -0.7910, -1.2187, -0.7158,  0.4088,
#          -1.1220,  0.3500, -2.8075, -0.7395, -0.5940, -0.3484, -0.4839]])
# tensor([[ 0.0929, -0.0618,  0.0869, -0.2843,  0.0390, -0.7442, -0.5182, -0.1214,
#          -0.3653, -1.6980, -1.3661,  0.2139,  0.0890,  0.4681, -1.6811, -0.9844,
#          -0.7595,  0.3938, -0.5233,  0.3760]])
